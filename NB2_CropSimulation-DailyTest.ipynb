# %% [markdown]
# <br>

# %% [markdown]
# # Notebook II - Crop Simulation
#
# <hr>
# <hr>

# %% [markdown]
# ## Importing Libraries

# %%
'''import supporting libraries'''

import numpy as np
import matplotlib.pyplot as plt
import imageio

import sys
sys.path.append('./code/') # add path to source code directory

# %% [markdown]
# ## Reading Data

# %%
'''reading climate data'''

min_temp = np.load('./sample_data/input/climate/min_temp.npy') # Celcius
max_temp = np.load('./sample_data/input/climate/max_temp.npy') # Celcius
precipitation = np.load('./sample_data/input/climate/precipitation.npy') # mm / day
short_rad = np.load('./sample_data/input/climate/short_rad.npy') # W/m^2
wind_speed = np.load('./sample_data/input/climate/wind_speed.npy') # m/s
rel_humidity = np.load('./sample_data/input/climate/relative_humidity.npy') # Fraction, and assumed as a constant 0.70

# %%
'''reading study area and elevation data'''

admin_mask = imageio.imread('./sample_data/input/LAO_Admin.tif');
srtm_elevation = imageio.imread('./sample_data/input/SRTM_Elevation.tif'); # m

# %%
import UtilitiesCalc
obj_utilities = UtilitiesCalc.UtilitiesCalc()

im_height = admin_mask.shape[0]
im_width = admin_mask.shape[1]

min_temp_d = np.zeros((im_height,im_width,365))
max_temp_d = np.zeros((im_height,im_width,365))
precipitation_d = np.zeros((im_height,im_width,365))
short_rad_d = np.zeros((im_height,im_width,365))
wind_speed_d = np.zeros((im_height,im_width,365))
rel_humidity_d = np.zeros((im_height,im_width,365))

for i_row in range(im_height):
    for i_col in range(im_width):
        min_temp_d[i_row,i_col,:] = obj_utilities.interpMonthlyToDaily(min_temp[i_row,i_col,:], 1, 365, False)
        max_temp_d[i_row,i_col,:] = obj_utilities.interpMonthlyToDaily(max_temp[i_row,i_col,:], 1, 365, False)
        precipitation_d[i_row,i_col,:] = obj_utilities.interpMonthlyToDaily(precipitation[i_row,i_col,:], 1, 365, True)
        short_rad_d[i_row,i_col,:] = obj_utilities.interpMonthlyToDaily(short_rad[i_row,i_col,:], 1, 365, True)
        wind_speed_d[i_row,i_col,:] = obj_utilities.interpMonthlyToDaily(wind_speed[i_row,i_col,:], 1, 365, True)
        rel_humidity_d[i_row,i_col,:] = obj_utilities.interpMonthlyToDaily(rel_humidity[i_row,i_col,:], 1, 365, True)
# Out:
# ./code\UtilitiesCalc.py:18: RuntimeWarning: invalid value encountered in less
#   daily_vector[daily_vector<0] = 0

# %% [markdown]
# ## Crop Simulation

# %%
'''importing library'''

import CropSimulation
aez = CropSimulation.CropSimulation()

import UtilitiesCalc
obj_utilities = UtilitiesCalc.UtilitiesCalc()

# %%
'''setting input data'''

# latitude limits of the study area
lat_min = 13.90
lat_max = 22.51

aez.setDailyClimateData(min_temp_d, max_temp_d, precipitation_d, short_rad_d, wind_speed_d, rel_humidity_d)
aez.setLocationTerrainData(lat_min=lat_min, lat_max=lat_max, elevation=srtm_elevation)
aez.setCropParameters(LAI=4, HI=0.4, legume=0, adaptability=2, cycle_len=105, D1=0.75, D2=0.75)
aez.setCropCycleParameters(stage_per=[10, 30, 30, 30], kc=[1.1, 1.2, 1], kc_all=1.1, yloss_f=[1, 2, 2.5, 1], yloss_f_all=2)
aez.setSoilWaterParameters(Sa=100*np.ones(()), pc=0.5)

# %%
'''setting study area, climate screening (optional)'''

aez.setStudyAreaMask(admin_mask=admin_mask, no_data_value=0)

#tclimate = imageio.imread('.\Outputs\OutputV1_25Km\ThermalClimate.tif');
#aez.setThermalClimateScreening(tclimate, [1,2])

aez.setLGPTScreening([75,75,75],[105,105,105])
aez.setTSumScreening([2000,2000,2000],[3000,3000,3000])

#tprofile_1 = [100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100]
#aez.setTProfileScreening(tprofile_1,tprofile_1)

# %%
'''run simulations'''

aez.simulateCropCycle() # results are in kg / hectare
# Out:
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 0 %
# Done: 1 %
# Done: 1 %
# Done: 1 %
# Done: 1 %
# Done: 1 %
# Done: 2 %
# Done: 2 %
# Done: 2 %
# Done: 2 %
# Done: 3 %
# Done: 3 %
# Done: 3 %
# Done: 3 %
# Done: 4 %
# Done: 4 %
# Done: 4 %
# Done: 5 %
# Done: 5 %
# Done: 5 %
# Done: 6 %
# Done: 6 %
# Done: 6 %
# Done: 7 %
# Done: 8 %
# Done: 8 %
# Done: 9 %
# Done: 9 %
# Done: 10 %
# Done: 11 %
# Done: 12 %
# Done: 12 %
# Done: 13 %
# Done: 14 %
# Done: 15 %
# Done: 16 %
# Done: 17 %
# Done: 18 %
# Done: 19 %
# Done: 20 %
# Done: 21 %
# Done: 22 %
# Done: 23 %
# Done: 24 %
# Done: 25 %
# Done: 26 %
# Done: 27 %
# Done: 28 %
# Done: 29 %
# Done: 30 %
# Done: 31 %
# Done: 32 %
# Done: 33 %
# Done: 34 %
# Done: 35 %
# Done: 36 %
# Done: 37 %
# Done: 38 %
# Done: 38 %
# Done: 39 %
# Done: 40 %
# Done: 40 %
# Done: 41 %
# Done: 42 %
# Done: 42 %
# Done: 43 %
# Done: 44 %
# Done: 44 %
# Done: 45 %
# Done: 46 %
# Done: 46 %
# Done: 47 %
# Done: 48 %
# Done: 49 %
# Done: 49 %
# Done: 50 %
# Done: 51 %
# Done: 52 %
# Done: 53 %
# Done: 54 %
# Done: 55 %
# Done: 56 %
# Done: 56 %
# Done: 57 %
# Done: 58 %
# Done: 59 %
# Done: 60 %
# Done: 61 %
# Done: 61 %
# Done: 62 %
# Done: 63 %
# Done: 63 %
# Done: 64 %
# Done: 65 %
# Done: 65 %
# Done: 66 %
# Done: 66 %
# Done: 66 %
# Done: 67 %
# Done: 67 %
# Done: 68 %
# Done: 68 %
# Done: 68 %
# Done: 69 %
# Done: 69 %
# Done: 69 %
# Done: 70 %
# Done: 70 %
# Done: 70 %
# Done: 71 %
# Done: 71 %
# Done: 71 %
# Done: 72 %
# Done: 72 %
# Done: 72 %
# Done: 73 %
# Done: 73 %
# Done: 74 %
# Done: 74 %
# Done: 74 %
# Done: 75 %
# Done: 75 %
# Done: 76 %
# Done: 76 %
# Done: 77 %
# Done: 77 %
# Done: 77 %
# Done: 78 %
# Done: 78 %
# Done: 79 %
# Done: 79 %
# Done: 80 %
# Done: 80 %
# Done: 81 %
# Done: 81 %
# Done: 82 %
# Done: 82 %
# Done: 83 %
# Done: 83 %
# Done: 84 %
# Done: 84 %
# Done: 84 %
# Done: 85 %
# Done: 85 %
# Done: 86 %
# Done: 86 %
# Done: 86 %
# Done: 87 %
# Done: 87 %
# Done: 88 %
# Done: 88 %
# Done: 89 %
# Done: 89 %
# Done: 90 %
# Done: 90 %
# Done: 90 %
# Done: 91 %
# Done: 91 %
# Done: 92 %
# Done: 92 %
# Done: 93 %
# Done: 93 %
# Done: 94 %
# Done: 94 %
# Done: 95 %
# Done: 95 %
# Done: 96 %
# Done: 96 %
# Done: 96 %
# Done: 97 %
# Done: 97 %
# Done: 98 %
# Done: 98 %
# Done: 98 %
# Done: 98 %
# Done: 99 %
# Done: 99 %
# Done: 99 %
# Done: 99 %
# Done: 99 %
# Done: 99 %
# Done: 99 %
# Done: 99 %
# Done: 100 %
# Simulations Completed !

# %%
'''get result'''

yield_map_rain = aez.getEstimatedYieldRainfed()
yield_map_irr = aez.getEstimatedYieldIrrigated()

starting_date = aez.getOptimumCycleStartDate()

## get classified output
yield_map_rain_class = obj_utilities.classifyFinalYield(yield_map_rain)
yield_map_irr_class = obj_utilities.classifyFinalYield(yield_map_irr)

# %%
'''visualize result'''

plt.imshow(yield_map_rain)
plt.show()
plt.imshow(yield_map_irr)
plt.show()

plt.imshow(starting_date)
plt.show()

plt.imshow(yield_map_rain_class)
plt.show()
plt.imshow(yield_map_irr_class)
plt.show()

# %%
'''save result'''

obj_utilities.saveRaster('./sample_data/input/LAO_Admin.tif', './sample_data/output/NB2/CropSuitability_rain.tif', yield_map_rain)
obj_utilities.saveRaster('./sample_data/input/LAO_Admin.tif', './sample_data/output/NB2/CropSuitability_irr.tif', yield_map_irr)

obj_utilities.saveRaster('./sample_data/input/LAO_Admin.tif', './sample_data/output/NB2/Starting_date.tif', starting_date)

obj_utilities.saveRaster('./sample_data/input/LAO_Admin.tif', './sample_data/output/NB2/CropSuitability_rain_class.tif',yield_map_rain_class)
obj_utilities.saveRaster('./sample_data/input/LAO_Admin.tif', './sample_data/output/NB2/CropSuitability_irr_class.tif',yield_map_irr_class)
